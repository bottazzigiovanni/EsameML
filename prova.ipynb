# %%
#installo le librerie
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#carico il dataset
dataset_path = 'https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/immobili.csv'
df = pd.read_csv(dataset_path)
df
# Out:
#         crim    zn  indus chas    nox     rm   age     dis  rad  tax ptratio  \
# 0    0.00632  18.0   2.31    0  0.538  6.575  65.2    4.09    1  296    15.3
# 1    0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671    2  242    17.8
# 2    0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671    2  242    17.8
# 3    0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622    3  222    18.7
# 4    0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622    3  222    18.7
# ..       ...   ...    ...  ...    ...    ...   ...     ...  ...  ...     ...
# 502  0.04527   0.0  11.93    0  0.573   6.12  76.7  2.2875    1  273    21.0
# 503  0.06076   0.0  11.93    0  0.573  6.976  91.0  2.1675    1  273    21.0
# 504  0.10959   0.0  11.93    0  0.573  6.794  89.3  2.3889    1  273    21.0
# 505  0.04741   0.0  11.93    0  0.573   6.03  80.8   2.505    1  273    21.0
# 506       is   not      a   ro     ck     et    sc      ie  nce    i      sn
#
#           b lstat  medv
# ...

# %%
# Elimina l'ultima riga
df = df.drop(df.index[-1])

# %%
df = df.astype(float)

# %%
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad    tax  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# ...

# %%
#info del dataset 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    float64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    float64
#  9   tax      506 non-null    float64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
# Rinomina la colonna "medv" in "price"
df = df.rename(columns={"medv": "price"})

# %%
## 1 - Declare Features and target
X = df.drop(columns='price')
y = df['price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size = 0.2, 
                                                    random_state = 650
                                                    )

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

r2score = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)

print('R2_score: ', r2score)
print('MAE: ', mae)
print('MSE: ', mse)
print('RMSE: ', rmse)
# Out:
# R2_score:  0.7362991679399118
# MAE:  2.8478611538585334
# MSE:  18.620768648052604
# RMSE:  4.315178866287306

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression(fit_intercept=True)
model.fit(X, y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([-1.08011358e-01,  4.64204584e-02,  2.05586264e-02,  2.68673382e+00,
#        -1.77666112e+01,  3.80986521e+00,  6.92224640e-04, -1.47556685e+00,
#         3.06049479e-01, -1.23345939e-02, -9.52747232e-01,  9.31168327e-03,
#        -5.24758378e-01])

# %%
model.intercept_
# Out:
# 36.45948838508985

# %%
y_pred = model.predict(X_test)

# %%
res_df = pd.DataFrame(data=list(zip(y_pred, y_test)),columns=['predicted', 'real'])
res_df
# Out:
#      predicted  real
# 0    29.113098  22.5
# 1    12.706097  10.5
# 2    24.206335  24.4
# 3    30.289341  30.5
# 4    29.081055  25.0
# ..         ...   ...
# 97   17.298873  23.2
# 98   15.178767  16.2
# 99   26.994861  23.9
# 100  15.678338  15.6
# 101  43.302390  50.0
#
# [102 rows x 2 columns]

# %%
res_df['error'] = res_df['real'] - res_df['predicted']
res_df
# Out:
#      predicted  real     error
# 0    29.113098  22.5 -6.613098
# 1    12.706097  10.5 -2.206097
# 2    24.206335  24.4  0.193665
# 3    30.289341  30.5  0.210659
# 4    29.081055  25.0 -4.081055
# ..         ...   ...       ...
# 97   17.298873  23.2  5.901127
# 98   15.178767  16.2  1.021233
# 99   26.994861  23.9 -3.094861
# 100  15.678338  15.6 -0.078338
# 101  43.302390  50.0  6.697610
#
# [102 rows x 3 columns]

# %%
res_df['error'].mean()
# Out:
# 0.025452939796260773

# %%
import joblib

# %%
joblib.dump(model,'prova_test.pkl')
# Out:
# ['prova_test.pkl']

# %%
newmodel = joblib.load('prova_test.pkl')
newmodel
# Out:
# LinearRegression()

# %%
newmodel.predict([[324,45,65,78,97,12,39,47,28,59,467,34,56]])[0]
# Out:
# -1998.6744587158175
